# %%
import numpy as np
import scipy as sp
import scipy.stats as sts
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 200)

# %%
alpha = 1
beta = 2
distribution = sts.gamma(a=alpha, scale=1/beta)
plt.figure(figsize=(10, 6))
plt.plot(x, distribution.pdf(x), label='a=1, b=2')

alpha = 2
beta = 2
distribution = sts.gamma(a=alpha, scale=1/beta)
plt.plot(x, distribution.pdf(x), label='a=2, b=2')

alpha = 1
beta = 1
distribution = sts.gamma(a=alpha, scale=1/beta)
plt.plot(x, distribution.pdf(x), label='a=1, b=1')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 4), dpi=300)
alpha = 2
beta = 1
distribution = sts.gamma(a=alpha, scale=1/beta)
plt.plot(x, distribution.pdf(x))

plt.show()

# %%
distribution.cdf(10)
# Out:
# 0.5768099188731566

# %%
samples = distribution.rvs(size=100)

plt.figure(figsize=(10, 6))
plt.hist(samples, density=True)
plt.plot(x, distribution.pdf(x))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-13434ef9b4d9> in <module>
# ----> 1 samples = distribution.rvs(size=100)
#       2
#       3 plt.figure(figsize=(10, 6))
#       4 plt.hist(samples, density=True)
#       5 plt.plot(x, distribution.pdf(x))
#
# NameError: name 'distribution' is not defined
